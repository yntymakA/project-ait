# %%
import requests
url = 'http://localhost:8000/categories'

data = {
  "name": "Недвижимость",
  "slug": "real-estate",
  "parent_id": null,
  "display_order": 1,
  "is_active": true
}

response = requests.post(data, url)
return response.json()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import requests
#       2 url = 'http://localhost:8000/categories'
#       4 data = {
#       5   "name": "Недвижимость",
#       6   "slug": "real-estate",
#    (...)      9   "is_active": true
#      10 }
#
# ModuleNotFoundError: No module named 'requests'
